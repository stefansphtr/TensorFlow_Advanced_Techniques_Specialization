# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split
# Out:
# WARNING:tensorflow:From c:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# WARNING:tensorflow:From c:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 8)]                  0         []
#
#  dense (Dense)               (None, 128)                  1152      ['input_1[0][0]']
#
#  dense_1 (Dense)             (None, 128)                  16512     ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 64)                   8256      ['dense_1[0][0]']
#
#  y1_output (Dense)           (None, 1)                    129       ['dense_1[0][0]']
#
#  y2_output (Dense)           (None, 1)                    65        ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 26114 (102.01 KB)
# Trainable params: 26114 (102.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/500
# WARNING:tensorflow:From c:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From c:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From c:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From c:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# 62/62 [==============================] - 2s 12ms/step - loss: 237.1617 - y1_output_loss: 115.3115 - y2_output_loss: 121.8503 - y1_output_root_mean_squared_error: 10.7383 - y2_output_root_mean_squared_error: 11.0386 - val_loss: 45.3594 - val_y1_output_loss: 17.0218 - val_y2_output_loss: 28.3375 - val_y1_output_root_mean_squared_error: 4.1258 - val_y2_output_root_mean_squared_error: 5.3233
# Epoch 2/500
# 62/62 [==============================] - 0s 4ms/step - loss: 31.4833 - y1_output_loss: 12.4240 - y2_output_loss: 19.0593 - y1_output_root_mean_squared_error: 3.5248 - y2_output_root_mean_squared_error: 4.3657 - val_loss: 22.2914 - val_y1_output_loss: 10.9404 - val_y2_output_loss: 11.3510 - val_y1_output_root_mean_squared_error: 3.3076 - val_y2_output_root_mean_squared_error: 3.3691
# Epoch 3/500
# 62/62 [==============================] - 0s 4ms/step - loss: 23.4936 - y1_output_loss: 9.2583 - y2_output_loss: 14.2353 - y1_output_root_mean_squared_error: 3.0427 - y2_output_root_mean_squared_error: 3.7730 - val_loss: 26.3836 - val_y1_output_loss: 12.1935 - val_y2_output_loss: 14.1902 - val_y1_output_root_mean_squared_error: 3.4919 - val_y2_output_root_mean_squared_error: 3.7670
# Epoch 4/500
# 62/62 [==============================] - 0s 3ms/step - loss: 22.4688 - y1_output_loss: 8.9056 - y2_output_loss: 13.5631 - y1_output_root_mean_squared_error: 2.9842 - y2_output_root_mean_squared_error: 3.6828 - val_loss: 24.5903 - val_y1_output_loss: 9.3652 - val_y2_output_loss: 15.2252 - val_y1_output_root_mean_squared_error: 3.0603 - val_y2_output_root_mean_squared_error: 3.9019
# Epoch 5/500
# 62/62 [==============================] - 0s 3ms/step - loss: 23.6054 - y1_output_loss: 8.7794 - y2_output_loss: 14.8260 - y1_output_root_mean_squared_error: 2.9630 - y2_output_root_mean_squared_error: 3.8505 - val_loss: 19.9056 - val_y1_output_loss: 8.4595 - val_y2_output_loss: 11.4461 - val_y1_output_root_mean_squared_error: 2.9085 - val_y2_output_root_mean_squared_error: 3.3832
# Epoch 6/500
# 62/62 [==============================] - 0s 3ms/step - loss: 24.0591 - y1_output_loss: 9.0501 - y2_output_loss: 15.0090 - y1_output_root_mean_squared_error: 3.0083 - y2_output_root_mean_squared_error: 3.8741 - val_loss: 55.0229 - val_y1_output_loss: 16.1919 - val_y2_output_loss: 38.8310 - val_y1_output_root_mean_squared_error: 4.0239 - val_y2_output_root_mean_squared_error: 6.2315
# Epoch 7/500
# 62/62 [==============================] - 0s 3ms/step - loss: 25.6339 - y1_output_loss: 9.3126 - y2_output_loss: 16.3213 - y1_output_root_mean_squared_error: 3.0517 - y2_output_root_mean_squared_error: 4.0400 - val_loss: 48.4102 - val_y1_output_loss: 12.2170 - val_y2_output_loss: 36.1932 - val_y1_output_root_mean_squared_error: 3.4953 - val_y2_output_root_mean_squared_error: 6.0161
# Epoch 8/500
# 62/62 [==============================] - 0s 3ms/step - loss: 22.4362 - y1_output_loss: 8.2396 - y2_output_loss: 14.1966 - y1_output_root_mean_squared_error: 2.8705 - y2_output_root_mean_squared_error: 3.7678 - val_loss: 57.5015 - val_y1_output_loss: 15.6337 - val_y2_output_loss: 41.8678 - val_y1_output_root_mean_squared_error: 3.9539 - val_y2_output_root_mean_squared_error: 6.4705
# Epoch 9/500
# 62/62 [==============================] - 0s 5ms/step - loss: 19.6904 - y1_output_loss: 7.5767 - y2_output_loss: 12.1137 - y1_output_root_mean_squared_error: 2.7526 - y2_output_root_mean_squared_error: 3.4805 - val_loss: 41.4750 - val_y1_output_loss: 11.8077 - val_y2_output_loss: 29.6673 - val_y1_output_root_mean_squared_error: 3.4362 - val_y2_output_root_mean_squared_error: 5.4468
# Epoch 10/500
# 62/62 [==============================] - 0s 3ms/step - loss: 19.4720 - y1_output_loss: 7.7089 - y2_output_loss: 11.7631 - y1_output_root_mean_squared_error: 2.7765 - y2_output_root_mean_squared_error: 3.4297 - val_loss: 17.6323 - val_y1_output_loss: 8.2421 - val_y2_output_loss: 9.3903 - val_y1_output_root_mean_squared_error: 2.8709 - val_y2_output_root_mean_squared_error: 3.0644
# Epoch 11/500
# 62/62 [==============================] - 0s 4ms/step - loss: 23.8686 - y1_output_loss: 7.9346 - y2_output_loss: 15.9340 - y1_output_root_mean_squared_error: 2.8168 - y2_output_root_mean_squared_error: 3.9917 - val_loss: 17.6478 - val_y1_output_loss: 7.0252 - val_y2_output_loss: 10.6226 - val_y1_output_root_mean_squared_error: 2.6505 - val_y2_output_root_mean_squared_error: 3.2592
# Epoch 12/500
# 62/62 [==============================] - 0s 3ms/step - loss: 20.1848 - y1_output_loss: 7.1172 - y2_output_loss: 13.0675 - y1_output_root_mean_squared_error: 2.6678 - y2_output_root_mean_squared_error: 3.6149 - val_loss: 62.9483 - val_y1_output_loss: 16.9456 - val_y2_output_loss: 46.0027 - val_y1_output_root_mean_squared_error: 4.1165 - val_y2_output_root_mean_squared_error: 6.7825
# Epoch 13/500
# 62/62 [==============================] - 0s 3ms/step - loss: 19.4088 - y1_output_loss: 6.9757 - y2_output_loss: 12.4331 - y1_output_root_mean_squared_error: 2.6412 - y2_output_root_mean_squared_error: 3.5261 - val_loss: 64.0085 - val_y1_output_loss: 15.8715 - val_y2_output_loss: 48.1370 - val_y1_output_root_mean_squared_error: 3.9839 - val_y2_output_root_mean_squared_error: 6.9381
# Epoch 14/500
# 62/62 [==============================] - 0s 5ms/step - loss: 16.9618 - y1_output_loss: 6.3103 - y2_output_loss: 10.6515 - y1_output_root_mean_squared_error: 2.5120 - y2_output_root_mean_squared_error: 3.2637 - val_loss: 50.6549 - val_y1_output_loss: 15.5434 - val_y2_output_loss: 35.1115 - val_y1_output_root_mean_squared_error: 3.9425 - val_y2_output_root_mean_squared_error: 5.9255
# Epoch 15/500
# 62/62 [==============================] - 0s 4ms/step - loss: 16.2750 - y1_output_loss: 5.9327 - y2_output_loss: 10.3423 - y1_output_root_mean_squared_error: 2.4357 - y2_output_root_mean_squared_error: 3.2159 - val_loss: 21.9032 - val_y1_output_loss: 7.1575 - val_y2_output_loss: 14.7458 - val_y1_output_root_mean_squared_error: 2.6753 - val_y2_output_root_mean_squared_error: 3.8400
# Epoch 16/500
# 62/62 [==============================] - 0s 3ms/step - loss: 15.6076 - y1_output_loss: 5.5896 - y2_output_loss: 10.0180 - y1_output_root_mean_squared_error: 2.3642 - y2_output_root_mean_squared_error: 3.1651 - val_loss: 27.8459 - val_y1_output_loss: 8.5899 - val_y2_output_loss: 19.2560 - val_y1_output_root_mean_squared_error: 2.9309 - val_y2_output_root_mean_squared_error: 4.3882
# Epoch 17/500
# 62/62 [==============================] - 0s 4ms/step - loss: 16.8310 - y1_output_loss: 5.6474 - y2_output_loss: 11.1836 - y1_output_root_mean_squared_error: 2.3764 - y2_output_root_mean_squared_error: 3.3442 - val_loss: 17.3338 - val_y1_output_loss: 5.9763 - val_y2_output_loss: 11.3575 - val_y1_output_root_mean_squared_error: 2.4446 - val_y2_output_root_mean_squared_error: 3.3701
# Epoch 18/500
# 62/62 [==============================] - 0s 4ms/step - loss: 13.6214 - y1_output_loss: 5.0404 - y2_output_loss: 8.5809 - y1_output_root_mean_squared_error: 2.2451 - y2_output_root_mean_squared_error: 2.9293 - val_loss: 12.4447 - val_y1_output_loss: 5.5903 - val_y2_output_loss: 6.8543 - val_y1_output_root_mean_squared_error: 2.3644 - val_y2_output_root_mean_squared_error: 2.6181
# Epoch 19/500
# 62/62 [==============================] - 0s 4ms/step - loss: 13.3820 - y1_output_loss: 4.9544 - y2_output_loss: 8.4277 - y1_output_root_mean_squared_error: 2.2258 - y2_output_root_mean_squared_error: 2.9030 - val_loss: 12.3144 - val_y1_output_loss: 5.1906 - val_y2_output_loss: 7.1238 - val_y1_output_root_mean_squared_error: 2.2783 - val_y2_output_root_mean_squared_error: 2.6691
# Epoch 20/500
# 62/62 [==============================] - 0s 6ms/step - loss: 15.1271 - y1_output_loss: 5.0782 - y2_output_loss: 10.0489 - y1_output_root_mean_squared_error: 2.2535 - y2_output_root_mean_squared_error: 3.1700 - val_loss: 12.2397 - val_y1_output_loss: 5.2481 - val_y2_output_loss: 6.9917 - val_y1_output_root_mean_squared_error: 2.2909 - val_y2_output_root_mean_squared_error: 2.6442
# Epoch 21/500
# 62/62 [==============================] - 0s 3ms/step - loss: 13.7312 - y1_output_loss: 4.6022 - y2_output_loss: 9.1290 - y1_output_root_mean_squared_error: 2.1453 - y2_output_root_mean_squared_error: 3.0214 - val_loss: 12.7585 - val_y1_output_loss: 5.3948 - val_y2_output_loss: 7.3637 - val_y1_output_root_mean_squared_error: 2.3227 - val_y2_output_root_mean_squared_error: 2.7136
# Epoch 22/500
# 62/62 [==============================] - 0s 5ms/step - loss: 14.5282 - y1_output_loss: 4.7952 - y2_output_loss: 9.7331 - y1_output_root_mean_squared_error: 2.1898 - y2_output_root_mean_squared_error: 3.1198 - val_loss: 24.0593 - val_y1_output_loss: 6.3084 - val_y2_output_loss: 17.7508 - val_y1_output_root_mean_squared_error: 2.5117 - val_y2_output_root_mean_squared_error: 4.2132
# Epoch 23/500
# 62/62 [==============================] - 0s 4ms/step - loss: 10.3415 - y1_output_loss: 3.7945 - y2_output_loss: 6.5470 - y1_output_root_mean_squared_error: 1.9479 - y2_output_root_mean_squared_error: 2.5587 - val_loss: 12.6630 - val_y1_output_loss: 4.6436 - val_y2_output_loss: 8.0195 - val_y1_output_root_mean_squared_error: 2.1549 - val_y2_output_root_mean_squared_error: 2.8319
# Epoch 24/500
# 62/62 [==============================] - 0s 3ms/step - loss: 10.8560 - y1_output_loss: 3.7317 - y2_output_loss: 7.1243 - y1_output_root_mean_squared_error: 1.9318 - y2_output_root_mean_squared_error: 2.6691 - val_loss: 9.6974 - val_y1_output_loss: 4.4088 - val_y2_output_loss: 5.2885 - val_y1_output_root_mean_squared_error: 2.0997 - val_y2_output_root_mean_squared_error: 2.2997
# Epoch 25/500
# 62/62 [==============================] - 0s 3ms/step - loss: 12.0080 - y1_output_loss: 4.1050 - y2_output_loss: 7.9029 - y1_output_root_mean_squared_error: 2.0261 - y2_output_root_mean_squared_error: 2.8112 - val_loss: 10.7512 - val_y1_output_loss: 4.6332 - val_y2_output_loss: 6.1180 - val_y1_output_root_mean_squared_error: 2.1525 - val_y2_output_root_mean_squared_error: 2.4735
# Epoch 26/500
# 62/62 [==============================] - 0s 4ms/step - loss: 10.0935 - y1_output_loss: 3.4141 - y2_output_loss: 6.6794 - y1_output_root_mean_squared_error: 1.8477 - y2_output_root_mean_squared_error: 2.5845 - val_loss: 9.2514 - val_y1_output_loss: 4.0391 - val_y2_output_loss: 5.2123 - val_y1_output_root_mean_squared_error: 2.0098 - val_y2_output_root_mean_squared_error: 2.2831
# Epoch 27/500
# 62/62 [==============================] - 0s 4ms/step - loss: 12.0375 - y1_output_loss: 4.0835 - y2_output_loss: 7.9540 - y1_output_root_mean_squared_error: 2.0208 - y2_output_root_mean_squared_error: 2.8203 - val_loss: 9.4338 - val_y1_output_loss: 3.9980 - val_y2_output_loss: 5.4358 - val_y1_output_root_mean_squared_error: 1.9995 - val_y2_output_root_mean_squared_error: 2.3315
# Epoch 28/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.7384 - y1_output_loss: 3.4716 - y2_output_loss: 6.2668 - y1_output_root_mean_squared_error: 1.8632 - y2_output_root_mean_squared_error: 2.5034 - val_loss: 12.3517 - val_y1_output_loss: 5.3087 - val_y2_output_loss: 7.0430 - val_y1_output_root_mean_squared_error: 2.3041 - val_y2_output_root_mean_squared_error: 2.6539
# Epoch 29/500
# 62/62 [==============================] - 0s 4ms/step - loss: 10.3710 - y1_output_loss: 3.2266 - y2_output_loss: 7.1445 - y1_output_root_mean_squared_error: 1.7963 - y2_output_root_mean_squared_error: 2.6729 - val_loss: 12.3782 - val_y1_output_loss: 5.3491 - val_y2_output_loss: 7.0290 - val_y1_output_root_mean_squared_error: 2.3128 - val_y2_output_root_mean_squared_error: 2.6512
# Epoch 30/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.7381 - y1_output_loss: 2.9213 - y2_output_loss: 5.8168 - y1_output_root_mean_squared_error: 1.7092 - y2_output_root_mean_squared_error: 2.4118 - val_loss: 7.8863 - val_y1_output_loss: 3.2597 - val_y2_output_loss: 4.6266 - val_y1_output_root_mean_squared_error: 1.8055 - val_y2_output_root_mean_squared_error: 2.1510
# Epoch 31/500
# 62/62 [==============================] - 0s 5ms/step - loss: 9.5356 - y1_output_loss: 3.1742 - y2_output_loss: 6.3614 - y1_output_root_mean_squared_error: 1.7816 - y2_output_root_mean_squared_error: 2.5222 - val_loss: 11.0311 - val_y1_output_loss: 4.6510 - val_y2_output_loss: 6.3801 - val_y1_output_root_mean_squared_error: 2.1566 - val_y2_output_root_mean_squared_error: 2.5259
# Epoch 32/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.8212 - y1_output_loss: 3.2230 - y2_output_loss: 6.5982 - y1_output_root_mean_squared_error: 1.7953 - y2_output_root_mean_squared_error: 2.5687 - val_loss: 9.5316 - val_y1_output_loss: 3.9049 - val_y2_output_loss: 5.6267 - val_y1_output_root_mean_squared_error: 1.9761 - val_y2_output_root_mean_squared_error: 2.3721
# Epoch 33/500
# 62/62 [==============================] - 0s 4ms/step - loss: 8.9677 - y1_output_loss: 2.9596 - y2_output_loss: 6.0081 - y1_output_root_mean_squared_error: 1.7204 - y2_output_root_mean_squared_error: 2.4511 - val_loss: 12.6982 - val_y1_output_loss: 3.7510 - val_y2_output_loss: 8.9472 - val_y1_output_root_mean_squared_error: 1.9367 - val_y2_output_root_mean_squared_error: 2.9912
# Epoch 34/500
# 62/62 [==============================] - 0s 4ms/step - loss: 8.4910 - y1_output_loss: 2.9717 - y2_output_loss: 5.5193 - y1_output_root_mean_squared_error: 1.7239 - y2_output_root_mean_squared_error: 2.3493 - val_loss: 16.2901 - val_y1_output_loss: 7.6588 - val_y2_output_loss: 8.6314 - val_y1_output_root_mean_squared_error: 2.7675 - val_y2_output_root_mean_squared_error: 2.9379
# Epoch 35/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.4273 - y1_output_loss: 2.4318 - y2_output_loss: 4.9955 - y1_output_root_mean_squared_error: 1.5594 - y2_output_root_mean_squared_error: 2.2351 - val_loss: 6.8395 - val_y1_output_loss: 2.7436 - val_y2_output_loss: 4.0959 - val_y1_output_root_mean_squared_error: 1.6564 - val_y2_output_root_mean_squared_error: 2.0238
# Epoch 36/500
# 62/62 [==============================] - 0s 4ms/step - loss: 9.8614 - y1_output_loss: 2.9314 - y2_output_loss: 6.9301 - y1_output_root_mean_squared_error: 1.7121 - y2_output_root_mean_squared_error: 2.6325 - val_loss: 20.5869 - val_y1_output_loss: 4.5759 - val_y2_output_loss: 16.0110 - val_y1_output_root_mean_squared_error: 2.1391 - val_y2_output_root_mean_squared_error: 4.0014
# Epoch 37/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.5273 - y1_output_loss: 2.9101 - y2_output_loss: 6.6172 - y1_output_root_mean_squared_error: 1.7059 - y2_output_root_mean_squared_error: 2.5724 - val_loss: 9.8954 - val_y1_output_loss: 4.0407 - val_y2_output_loss: 5.8546 - val_y1_output_root_mean_squared_error: 2.0102 - val_y2_output_root_mean_squared_error: 2.4196
# Epoch 38/500
# 62/62 [==============================] - 0s 3ms/step - loss: 11.6545 - y1_output_loss: 3.6772 - y2_output_loss: 7.9773 - y1_output_root_mean_squared_error: 1.9176 - y2_output_root_mean_squared_error: 2.8244 - val_loss: 12.5930 - val_y1_output_loss: 4.0956 - val_y2_output_loss: 8.4973 - val_y1_output_root_mean_squared_error: 2.0238 - val_y2_output_root_mean_squared_error: 2.9150
# Epoch 39/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.1161 - y1_output_loss: 2.3797 - y2_output_loss: 5.7364 - y1_output_root_mean_squared_error: 1.5426 - y2_output_root_mean_squared_error: 2.3951 - val_loss: 9.6476 - val_y1_output_loss: 2.9773 - val_y2_output_loss: 6.6703 - val_y1_output_root_mean_squared_error: 1.7255 - val_y2_output_root_mean_squared_error: 2.5827
# Epoch 40/500
# 62/62 [==============================] - 0s 4ms/step - loss: 8.4121 - y1_output_loss: 2.5904 - y2_output_loss: 5.8217 - y1_output_root_mean_squared_error: 1.6095 - y2_output_root_mean_squared_error: 2.4128 - val_loss: 9.7401 - val_y1_output_loss: 3.6709 - val_y2_output_loss: 6.0691 - val_y1_output_root_mean_squared_error: 1.9160 - val_y2_output_root_mean_squared_error: 2.4636
# Epoch 41/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.2927 - y1_output_loss: 2.2717 - y2_output_loss: 5.0210 - y1_output_root_mean_squared_error: 1.5072 - y2_output_root_mean_squared_error: 2.2408 - val_loss: 7.1381 - val_y1_output_loss: 2.8654 - val_y2_output_loss: 4.2727 - val_y1_output_root_mean_squared_error: 1.6928 - val_y2_output_root_mean_squared_error: 2.0670
# Epoch 42/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.2594 - y1_output_loss: 2.3372 - y2_output_loss: 4.9223 - y1_output_root_mean_squared_error: 1.5288 - y2_output_root_mean_squared_error: 2.2186 - val_loss: 19.2148 - val_y1_output_loss: 5.7222 - val_y2_output_loss: 13.4926 - val_y1_output_root_mean_squared_error: 2.3921 - val_y2_output_root_mean_squared_error: 3.6732
# Epoch 43/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.7403 - y1_output_loss: 2.5610 - y2_output_loss: 5.1793 - y1_output_root_mean_squared_error: 1.6003 - y2_output_root_mean_squared_error: 2.2758 - val_loss: 11.8034 - val_y1_output_loss: 5.2079 - val_y2_output_loss: 6.5955 - val_y1_output_root_mean_squared_error: 2.2821 - val_y2_output_root_mean_squared_error: 2.5682
# Epoch 44/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.8910 - y1_output_loss: 3.0062 - y2_output_loss: 6.8848 - y1_output_root_mean_squared_error: 1.7338 - y2_output_root_mean_squared_error: 2.6239 - val_loss: 6.5590 - val_y1_output_loss: 2.3837 - val_y2_output_loss: 4.1753 - val_y1_output_root_mean_squared_error: 1.5439 - val_y2_output_root_mean_squared_error: 2.0434
# Epoch 45/500
# 62/62 [==============================] - 0s 4ms/step - loss: 8.3680 - y1_output_loss: 2.5037 - y2_output_loss: 5.8642 - y1_output_root_mean_squared_error: 1.5823 - y2_output_root_mean_squared_error: 2.4216 - val_loss: 7.8672 - val_y1_output_loss: 2.8168 - val_y2_output_loss: 5.0504 - val_y1_output_root_mean_squared_error: 1.6783 - val_y2_output_root_mean_squared_error: 2.2473
# Epoch 46/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.8896 - y1_output_loss: 2.1426 - y2_output_loss: 4.7470 - y1_output_root_mean_squared_error: 1.4638 - y2_output_root_mean_squared_error: 2.1788 - val_loss: 6.7253 - val_y1_output_loss: 2.4108 - val_y2_output_loss: 4.3145 - val_y1_output_root_mean_squared_error: 1.5527 - val_y2_output_root_mean_squared_error: 2.0771
# Epoch 47/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.6086 - y1_output_loss: 1.9520 - y2_output_loss: 4.6566 - y1_output_root_mean_squared_error: 1.3971 - y2_output_root_mean_squared_error: 2.1579 - val_loss: 9.5042 - val_y1_output_loss: 2.2748 - val_y2_output_loss: 7.2293 - val_y1_output_root_mean_squared_error: 1.5083 - val_y2_output_root_mean_squared_error: 2.6887
# Epoch 48/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.2070 - y1_output_loss: 1.9881 - y2_output_loss: 4.2188 - y1_output_root_mean_squared_error: 1.4100 - y2_output_root_mean_squared_error: 2.0540 - val_loss: 7.9533 - val_y1_output_loss: 2.4633 - val_y2_output_loss: 5.4901 - val_y1_output_root_mean_squared_error: 1.5695 - val_y2_output_root_mean_squared_error: 2.3431
# Epoch 49/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.8172 - y1_output_loss: 2.2740 - y2_output_loss: 4.5432 - y1_output_root_mean_squared_error: 1.5080 - y2_output_root_mean_squared_error: 2.1315 - val_loss: 19.7158 - val_y1_output_loss: 7.5353 - val_y2_output_loss: 12.1805 - val_y1_output_root_mean_squared_error: 2.7450 - val_y2_output_root_mean_squared_error: 3.4901
# Epoch 50/500
# 62/62 [==============================] - 0s 5ms/step - loss: 11.1896 - y1_output_loss: 3.5777 - y2_output_loss: 7.6119 - y1_output_root_mean_squared_error: 1.8915 - y2_output_root_mean_squared_error: 2.7590 - val_loss: 7.7030 - val_y1_output_loss: 3.0473 - val_y2_output_loss: 4.6557 - val_y1_output_root_mean_squared_error: 1.7456 - val_y2_output_root_mean_squared_error: 2.1577
# Epoch 51/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.4595 - y1_output_loss: 1.6806 - y2_output_loss: 3.7788 - y1_output_root_mean_squared_error: 1.2964 - y2_output_root_mean_squared_error: 1.9439 - val_loss: 6.5835 - val_y1_output_loss: 2.4810 - val_y2_output_loss: 4.1025 - val_y1_output_root_mean_squared_error: 1.5751 - val_y2_output_root_mean_squared_error: 2.0255
# Epoch 52/500
# 62/62 [==============================] - 0s 4ms/step - loss: 9.0606 - y1_output_loss: 2.8865 - y2_output_loss: 6.1741 - y1_output_root_mean_squared_error: 1.6990 - y2_output_root_mean_squared_error: 2.4848 - val_loss: 8.5123 - val_y1_output_loss: 3.3084 - val_y2_output_loss: 5.2040 - val_y1_output_root_mean_squared_error: 1.8189 - val_y2_output_root_mean_squared_error: 2.2812
# Epoch 53/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.6750 - y1_output_loss: 2.1736 - y2_output_loss: 5.5014 - y1_output_root_mean_squared_error: 1.4743 - y2_output_root_mean_squared_error: 2.3455 - val_loss: 16.0475 - val_y1_output_loss: 4.1619 - val_y2_output_loss: 11.8856 - val_y1_output_root_mean_squared_error: 2.0401 - val_y2_output_root_mean_squared_error: 3.4475
# Epoch 54/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.1201 - y1_output_loss: 1.9874 - y2_output_loss: 5.1326 - y1_output_root_mean_squared_error: 1.4098 - y2_output_root_mean_squared_error: 2.2655 - val_loss: 6.8767 - val_y1_output_loss: 2.5471 - val_y2_output_loss: 4.3296 - val_y1_output_root_mean_squared_error: 1.5960 - val_y2_output_root_mean_squared_error: 2.0808
# Epoch 55/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.7514 - y1_output_loss: 2.0164 - y2_output_loss: 4.7350 - y1_output_root_mean_squared_error: 1.4200 - y2_output_root_mean_squared_error: 2.1760 - val_loss: 7.5758 - val_y1_output_loss: 3.3659 - val_y2_output_loss: 4.2099 - val_y1_output_root_mean_squared_error: 1.8347 - val_y2_output_root_mean_squared_error: 2.0518
# Epoch 56/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.6585 - y1_output_loss: 1.6361 - y2_output_loss: 4.0224 - y1_output_root_mean_squared_error: 1.2791 - y2_output_root_mean_squared_error: 2.0056 - val_loss: 21.9870 - val_y1_output_loss: 8.1655 - val_y2_output_loss: 13.8215 - val_y1_output_root_mean_squared_error: 2.8575 - val_y2_output_root_mean_squared_error: 3.7177
# Epoch 57/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.8371 - y1_output_loss: 1.9122 - y2_output_loss: 3.9249 - y1_output_root_mean_squared_error: 1.3828 - y2_output_root_mean_squared_error: 1.9811 - val_loss: 6.5383 - val_y1_output_loss: 1.7736 - val_y2_output_loss: 4.7648 - val_y1_output_root_mean_squared_error: 1.3318 - val_y2_output_root_mean_squared_error: 2.1828
# Epoch 58/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.2110 - y1_output_loss: 1.9520 - y2_output_loss: 5.2590 - y1_output_root_mean_squared_error: 1.3971 - y2_output_root_mean_squared_error: 2.2932 - val_loss: 6.0836 - val_y1_output_loss: 1.7693 - val_y2_output_loss: 4.3143 - val_y1_output_root_mean_squared_error: 1.3301 - val_y2_output_root_mean_squared_error: 2.0771
# Epoch 59/500
# 62/62 [==============================] - 0s 5ms/step - loss: 4.7782 - y1_output_loss: 1.4563 - y2_output_loss: 3.3218 - y1_output_root_mean_squared_error: 1.2068 - y2_output_root_mean_squared_error: 1.8226 - val_loss: 5.7163 - val_y1_output_loss: 1.8265 - val_y2_output_loss: 3.8897 - val_y1_output_root_mean_squared_error: 1.3515 - val_y2_output_root_mean_squared_error: 1.9722
# Epoch 60/500
# 62/62 [==============================] - 0s 4ms/step - loss: 14.7812 - y1_output_loss: 4.7735 - y2_output_loss: 10.0077 - y1_output_root_mean_squared_error: 2.1848 - y2_output_root_mean_squared_error: 3.1635 - val_loss: 4.7867 - val_y1_output_loss: 1.5600 - val_y2_output_loss: 3.2268 - val_y1_output_root_mean_squared_error: 1.2490 - val_y2_output_root_mean_squared_error: 1.7963
# Epoch 61/500
# 62/62 [==============================] - 0s 3ms/step - loss: 4.6717 - y1_output_loss: 1.2746 - y2_output_loss: 3.3971 - y1_output_root_mean_squared_error: 1.1290 - y2_output_root_mean_squared_error: 1.8431 - val_loss: 4.4830 - val_y1_output_loss: 1.4200 - val_y2_output_loss: 3.0630 - val_y1_output_root_mean_squared_error: 1.1916 - val_y2_output_root_mean_squared_error: 1.7501
# Epoch 62/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5973 - y1_output_loss: 1.3961 - y2_output_loss: 4.2013 - y1_output_root_mean_squared_error: 1.1815 - y2_output_root_mean_squared_error: 2.0497 - val_loss: 5.1235 - val_y1_output_loss: 1.9123 - val_y2_output_loss: 3.2112 - val_y1_output_root_mean_squared_error: 1.3829 - val_y2_output_root_mean_squared_error: 1.7920
# Epoch 63/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.1188 - y1_output_loss: 1.3993 - y2_output_loss: 3.7195 - y1_output_root_mean_squared_error: 1.1829 - y2_output_root_mean_squared_error: 1.9286 - val_loss: 6.1162 - val_y1_output_loss: 1.5080 - val_y2_output_loss: 4.6082 - val_y1_output_root_mean_squared_error: 1.2280 - val_y2_output_root_mean_squared_error: 2.1467
# Epoch 64/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.0025 - y1_output_loss: 1.7070 - y2_output_loss: 4.2956 - y1_output_root_mean_squared_error: 1.3065 - y2_output_root_mean_squared_error: 2.0726 - val_loss: 4.8805 - val_y1_output_loss: 1.3627 - val_y2_output_loss: 3.5178 - val_y1_output_root_mean_squared_error: 1.1673 - val_y2_output_root_mean_squared_error: 1.8756
# Epoch 65/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.9112 - y1_output_loss: 1.3396 - y2_output_loss: 3.5716 - y1_output_root_mean_squared_error: 1.1574 - y2_output_root_mean_squared_error: 1.8899 - val_loss: 5.5882 - val_y1_output_loss: 1.9118 - val_y2_output_loss: 3.6764 - val_y1_output_root_mean_squared_error: 1.3827 - val_y2_output_root_mean_squared_error: 1.9174
# Epoch 66/500
# 62/62 [==============================] - 0s 5ms/step - loss: 8.7277 - y1_output_loss: 2.7046 - y2_output_loss: 6.0230 - y1_output_root_mean_squared_error: 1.6446 - y2_output_root_mean_squared_error: 2.4542 - val_loss: 6.0977 - val_y1_output_loss: 2.6021 - val_y2_output_loss: 3.4956 - val_y1_output_root_mean_squared_error: 1.6131 - val_y2_output_root_mean_squared_error: 1.8697
# Epoch 67/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.9138 - y1_output_loss: 1.3768 - y2_output_loss: 3.5370 - y1_output_root_mean_squared_error: 1.1734 - y2_output_root_mean_squared_error: 1.8807 - val_loss: 12.9069 - val_y1_output_loss: 2.1190 - val_y2_output_loss: 10.7880 - val_y1_output_root_mean_squared_error: 1.4557 - val_y2_output_root_mean_squared_error: 3.2845
# Epoch 68/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.5120 - y1_output_loss: 1.0554 - y2_output_loss: 3.4567 - y1_output_root_mean_squared_error: 1.0273 - y2_output_root_mean_squared_error: 1.8592 - val_loss: 4.9908 - val_y1_output_loss: 1.5841 - val_y2_output_loss: 3.4068 - val_y1_output_root_mean_squared_error: 1.2586 - val_y2_output_root_mean_squared_error: 1.8457
# Epoch 69/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.5791 - y1_output_loss: 0.9204 - y2_output_loss: 2.6587 - y1_output_root_mean_squared_error: 0.9594 - y2_output_root_mean_squared_error: 1.6306 - val_loss: 5.1321 - val_y1_output_loss: 1.4329 - val_y2_output_loss: 3.6992 - val_y1_output_root_mean_squared_error: 1.1971 - val_y2_output_root_mean_squared_error: 1.9233
# Epoch 70/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.9830 - y1_output_loss: 1.5133 - y2_output_loss: 4.4696 - y1_output_root_mean_squared_error: 1.2302 - y2_output_root_mean_squared_error: 2.1142 - val_loss: 5.4971 - val_y1_output_loss: 1.9126 - val_y2_output_loss: 3.5846 - val_y1_output_root_mean_squared_error: 1.3830 - val_y2_output_root_mean_squared_error: 1.8933
# Epoch 71/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.1041 - y1_output_loss: 1.9694 - y2_output_loss: 4.1347 - y1_output_root_mean_squared_error: 1.4033 - y2_output_root_mean_squared_error: 2.0334 - val_loss: 3.7748 - val_y1_output_loss: 1.0374 - val_y2_output_loss: 2.7374 - val_y1_output_root_mean_squared_error: 1.0185 - val_y2_output_root_mean_squared_error: 1.6545
# Epoch 72/500
# 62/62 [==============================] - 0s 4ms/step - loss: 8.1589 - y1_output_loss: 1.9526 - y2_output_loss: 6.2063 - y1_output_root_mean_squared_error: 1.3974 - y2_output_root_mean_squared_error: 2.4912 - val_loss: 5.8048 - val_y1_output_loss: 1.2206 - val_y2_output_loss: 4.5842 - val_y1_output_root_mean_squared_error: 1.1048 - val_y2_output_root_mean_squared_error: 2.1411
# Epoch 73/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.7174 - y1_output_loss: 0.8490 - y2_output_loss: 2.8684 - y1_output_root_mean_squared_error: 0.9214 - y2_output_root_mean_squared_error: 1.6936 - val_loss: 4.6732 - val_y1_output_loss: 1.2881 - val_y2_output_loss: 3.3851 - val_y1_output_root_mean_squared_error: 1.1349 - val_y2_output_root_mean_squared_error: 1.8399
# Epoch 74/500
# 62/62 [==============================] - 0s 5ms/step - loss: 5.2744 - y1_output_loss: 1.3901 - y2_output_loss: 3.8843 - y1_output_root_mean_squared_error: 1.1790 - y2_output_root_mean_squared_error: 1.9709 - val_loss: 4.5916 - val_y1_output_loss: 1.1377 - val_y2_output_loss: 3.4539 - val_y1_output_root_mean_squared_error: 1.0666 - val_y2_output_root_mean_squared_error: 1.8585
# Epoch 75/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.6873 - y1_output_loss: 0.9167 - y2_output_loss: 2.7706 - y1_output_root_mean_squared_error: 0.9575 - y2_output_root_mean_squared_error: 1.6645 - val_loss: 3.6117 - val_y1_output_loss: 0.9578 - val_y2_output_loss: 2.6539 - val_y1_output_root_mean_squared_error: 0.9787 - val_y2_output_root_mean_squared_error: 1.6291
# Epoch 76/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.1037 - y1_output_loss: 1.1280 - y2_output_loss: 2.9757 - y1_output_root_mean_squared_error: 1.0621 - y2_output_root_mean_squared_error: 1.7250 - val_loss: 11.2028 - val_y1_output_loss: 3.2695 - val_y2_output_loss: 7.9333 - val_y1_output_root_mean_squared_error: 1.8082 - val_y2_output_root_mean_squared_error: 2.8166
# Epoch 77/500
# 62/62 [==============================] - 0s 4ms/step - loss: 4.0554 - y1_output_loss: 0.9517 - y2_output_loss: 3.1037 - y1_output_root_mean_squared_error: 0.9755 - y2_output_root_mean_squared_error: 1.7617 - val_loss: 3.4964 - val_y1_output_loss: 0.8740 - val_y2_output_loss: 2.6224 - val_y1_output_root_mean_squared_error: 0.9349 - val_y2_output_root_mean_squared_error: 1.6194
# Epoch 78/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.2292 - y1_output_loss: 0.8284 - y2_output_loss: 2.4008 - y1_output_root_mean_squared_error: 0.9102 - y2_output_root_mean_squared_error: 1.5494 - val_loss: 4.1708 - val_y1_output_loss: 1.1630 - val_y2_output_loss: 3.0078 - val_y1_output_root_mean_squared_error: 1.0784 - val_y2_output_root_mean_squared_error: 1.7343
# Epoch 79/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.8384 - y1_output_loss: 1.0272 - y2_output_loss: 2.8111 - y1_output_root_mean_squared_error: 1.0135 - y2_output_root_mean_squared_error: 1.6766 - val_loss: 5.9372 - val_y1_output_loss: 2.0718 - val_y2_output_loss: 3.8654 - val_y1_output_root_mean_squared_error: 1.4394 - val_y2_output_root_mean_squared_error: 1.9661
# Epoch 80/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.3135 - y1_output_loss: 0.8253 - y2_output_loss: 2.4882 - y1_output_root_mean_squared_error: 0.9085 - y2_output_root_mean_squared_error: 1.5774 - val_loss: 8.8648 - val_y1_output_loss: 1.0956 - val_y2_output_loss: 7.7692 - val_y1_output_root_mean_squared_error: 1.0467 - val_y2_output_root_mean_squared_error: 2.7873
# Epoch 81/500
# 62/62 [==============================] - 0s 5ms/step - loss: 2.9103 - y1_output_loss: 0.6931 - y2_output_loss: 2.2172 - y1_output_root_mean_squared_error: 0.8325 - y2_output_root_mean_squared_error: 1.4890 - val_loss: 5.0937 - val_y1_output_loss: 1.4692 - val_y2_output_loss: 3.6245 - val_y1_output_root_mean_squared_error: 1.2121 - val_y2_output_root_mean_squared_error: 1.9038
# Epoch 82/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.7866 - y1_output_loss: 1.1687 - y2_output_loss: 2.6179 - y1_output_root_mean_squared_error: 1.0810 - y2_output_root_mean_squared_error: 1.6180 - val_loss: 3.1783 - val_y1_output_loss: 0.8449 - val_y2_output_loss: 2.3334 - val_y1_output_root_mean_squared_error: 0.9192 - val_y2_output_root_mean_squared_error: 1.5276
# Epoch 83/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.2970 - y1_output_loss: 0.7696 - y2_output_loss: 2.5274 - y1_output_root_mean_squared_error: 0.8773 - y2_output_root_mean_squared_error: 1.5898 - val_loss: 4.5765 - val_y1_output_loss: 0.9981 - val_y2_output_loss: 3.5784 - val_y1_output_root_mean_squared_error: 0.9990 - val_y2_output_root_mean_squared_error: 1.8917
# Epoch 84/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.1861 - y1_output_loss: 0.7596 - y2_output_loss: 2.4264 - y1_output_root_mean_squared_error: 0.8716 - y2_output_root_mean_squared_error: 1.5577 - val_loss: 3.0382 - val_y1_output_loss: 0.8306 - val_y2_output_loss: 2.2076 - val_y1_output_root_mean_squared_error: 0.9114 - val_y2_output_root_mean_squared_error: 1.4858
# Epoch 85/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.3040 - y1_output_loss: 0.7875 - y2_output_loss: 2.5165 - y1_output_root_mean_squared_error: 0.8874 - y2_output_root_mean_squared_error: 1.5863 - val_loss: 3.6234 - val_y1_output_loss: 0.9316 - val_y2_output_loss: 2.6918 - val_y1_output_root_mean_squared_error: 0.9652 - val_y2_output_root_mean_squared_error: 1.6407
# Epoch 86/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.0702 - y1_output_loss: 0.7636 - y2_output_loss: 2.3066 - y1_output_root_mean_squared_error: 0.8739 - y2_output_root_mean_squared_error: 1.5187 - val_loss: 9.2768 - val_y1_output_loss: 3.4982 - val_y2_output_loss: 5.7785 - val_y1_output_root_mean_squared_error: 1.8704 - val_y2_output_root_mean_squared_error: 2.4039
# Epoch 87/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.7462 - y1_output_loss: 0.6506 - y2_output_loss: 2.0956 - y1_output_root_mean_squared_error: 0.8066 - y2_output_root_mean_squared_error: 1.4476 - val_loss: 2.8536 - val_y1_output_loss: 0.9004 - val_y2_output_loss: 1.9532 - val_y1_output_root_mean_squared_error: 0.9489 - val_y2_output_root_mean_squared_error: 1.3976
# Epoch 88/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.6327 - y1_output_loss: 0.5902 - y2_output_loss: 2.0425 - y1_output_root_mean_squared_error: 0.7683 - y2_output_root_mean_squared_error: 1.4292 - val_loss: 14.5493 - val_y1_output_loss: 3.8677 - val_y2_output_loss: 10.6816 - val_y1_output_root_mean_squared_error: 1.9666 - val_y2_output_root_mean_squared_error: 3.2683
# Epoch 89/500
# 62/62 [==============================] - 0s 5ms/step - loss: 2.9122 - y1_output_loss: 0.7195 - y2_output_loss: 2.1927 - y1_output_root_mean_squared_error: 0.8482 - y2_output_root_mean_squared_error: 1.4808 - val_loss: 15.9127 - val_y1_output_loss: 3.2486 - val_y2_output_loss: 12.6641 - val_y1_output_root_mean_squared_error: 1.8024 - val_y2_output_root_mean_squared_error: 3.5587
# Epoch 90/500
# 62/62 [==============================] - 0s 4ms/step - loss: 12.7161 - y1_output_loss: 3.9163 - y2_output_loss: 8.7999 - y1_output_root_mean_squared_error: 1.9790 - y2_output_root_mean_squared_error: 2.9665 - val_loss: 3.6800 - val_y1_output_loss: 1.2934 - val_y2_output_loss: 2.3866 - val_y1_output_root_mean_squared_error: 1.1373 - val_y2_output_root_mean_squared_error: 1.5449
# Epoch 91/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.3140 - y1_output_loss: 0.6946 - y2_output_loss: 2.6194 - y1_output_root_mean_squared_error: 0.8334 - y2_output_root_mean_squared_error: 1.6185 - val_loss: 5.7974 - val_y1_output_loss: 0.8270 - val_y2_output_loss: 4.9704 - val_y1_output_root_mean_squared_error: 0.9094 - val_y2_output_root_mean_squared_error: 2.2294
# Epoch 92/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.5627 - y1_output_loss: 2.6027 - y2_output_loss: 5.9601 - y1_output_root_mean_squared_error: 1.6133 - y2_output_root_mean_squared_error: 2.4413 - val_loss: 5.9133 - val_y1_output_loss: 1.3417 - val_y2_output_loss: 4.5716 - val_y1_output_root_mean_squared_error: 1.1583 - val_y2_output_root_mean_squared_error: 2.1381
# Epoch 93/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.3675 - y1_output_loss: 0.8310 - y2_output_loss: 2.5366 - y1_output_root_mean_squared_error: 0.9116 - y2_output_root_mean_squared_error: 1.5927 - val_loss: 3.0011 - val_y1_output_loss: 0.9151 - val_y2_output_loss: 2.0860 - val_y1_output_root_mean_squared_error: 0.9566 - val_y2_output_root_mean_squared_error: 1.4443
# Epoch 94/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.6523 - y1_output_loss: 0.9065 - y2_output_loss: 2.7458 - y1_output_root_mean_squared_error: 0.9521 - y2_output_root_mean_squared_error: 1.6570 - val_loss: 2.5109 - val_y1_output_loss: 0.6560 - val_y2_output_loss: 1.8549 - val_y1_output_root_mean_squared_error: 0.8099 - val_y2_output_root_mean_squared_error: 1.3619
# Epoch 95/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.8520 - y1_output_loss: 0.6594 - y2_output_loss: 2.1926 - y1_output_root_mean_squared_error: 0.8120 - y2_output_root_mean_squared_error: 1.4807 - val_loss: 3.0821 - val_y1_output_loss: 0.8290 - val_y2_output_loss: 2.2532 - val_y1_output_root_mean_squared_error: 0.9105 - val_y2_output_root_mean_squared_error: 1.5011
# Epoch 96/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.6699 - y1_output_loss: 0.6122 - y2_output_loss: 2.0577 - y1_output_root_mean_squared_error: 0.7824 - y2_output_root_mean_squared_error: 1.4345 - val_loss: 3.0159 - val_y1_output_loss: 0.6660 - val_y2_output_loss: 2.3499 - val_y1_output_root_mean_squared_error: 0.8161 - val_y2_output_root_mean_squared_error: 1.5329
# Epoch 97/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.3137 - y1_output_loss: 0.7240 - y2_output_loss: 2.5897 - y1_output_root_mean_squared_error: 0.8509 - y2_output_root_mean_squared_error: 1.6092 - val_loss: 3.1050 - val_y1_output_loss: 1.0863 - val_y2_output_loss: 2.0187 - val_y1_output_root_mean_squared_error: 1.0423 - val_y2_output_root_mean_squared_error: 1.4208
# Epoch 98/500
# 62/62 [==============================] - 0s 3ms/step - loss: 3.3162 - y1_output_loss: 0.8165 - y2_output_loss: 2.4997 - y1_output_root_mean_squared_error: 0.9036 - y2_output_root_mean_squared_error: 1.5810 - val_loss: 4.1408 - val_y1_output_loss: 0.9268 - val_y2_output_loss: 3.2140 - val_y1_output_root_mean_squared_error: 0.9627 - val_y2_output_root_mean_squared_error: 1.7928
# Epoch 99/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.4739 - y1_output_loss: 0.5614 - y2_output_loss: 1.9125 - y1_output_root_mean_squared_error: 0.7493 - y2_output_root_mean_squared_error: 1.3829 - val_loss: 4.6149 - val_y1_output_loss: 1.5022 - val_y2_output_loss: 3.1128 - val_y1_output_root_mean_squared_error: 1.2256 - val_y2_output_root_mean_squared_error: 1.7643
# Epoch 100/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.7551 - y1_output_loss: 0.6253 - y2_output_loss: 2.1298 - y1_output_root_mean_squared_error: 0.7907 - y2_output_root_mean_squared_error: 1.4594 - val_loss: 3.6288 - val_y1_output_loss: 0.9052 - val_y2_output_loss: 2.7237 - val_y1_output_root_mean_squared_error: 0.9514 - val_y2_output_root_mean_squared_error: 1.6504
# Epoch 101/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.1270 - y1_output_loss: 0.6857 - y2_output_loss: 2.4413 - y1_output_root_mean_squared_error: 0.8281 - y2_output_root_mean_squared_error: 1.5625 - val_loss: 3.4557 - val_y1_output_loss: 0.6434 - val_y2_output_loss: 2.8124 - val_y1_output_root_mean_squared_error: 0.8021 - val_y2_output_root_mean_squared_error: 1.6770
# Epoch 102/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.8906 - y1_output_loss: 0.6016 - y2_output_loss: 2.2890 - y1_output_root_mean_squared_error: 0.7756 - y2_output_root_mean_squared_error: 1.5130 - val_loss: 3.5744 - val_y1_output_loss: 0.6938 - val_y2_output_loss: 2.8806 - val_y1_output_root_mean_squared_error: 0.8330 - val_y2_output_root_mean_squared_error: 1.6972
# Epoch 103/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.7396 - y1_output_loss: 0.6820 - y2_output_loss: 2.0577 - y1_output_root_mean_squared_error: 0.8258 - y2_output_root_mean_squared_error: 1.4345 - val_loss: 25.6226 - val_y1_output_loss: 7.3098 - val_y2_output_loss: 18.3128 - val_y1_output_root_mean_squared_error: 2.7037 - val_y2_output_root_mean_squared_error: 4.2793
# Epoch 104/500
# 62/62 [==============================] - 0s 5ms/step - loss: 3.7861 - y1_output_loss: 0.9598 - y2_output_loss: 2.8262 - y1_output_root_mean_squared_error: 0.9797 - y2_output_root_mean_squared_error: 1.6811 - val_loss: 11.0683 - val_y1_output_loss: 2.7805 - val_y2_output_loss: 8.2878 - val_y1_output_root_mean_squared_error: 1.6675 - val_y2_output_root_mean_squared_error: 2.8789
# Epoch 105/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.8084 - y1_output_loss: 0.6062 - y2_output_loss: 2.2022 - y1_output_root_mean_squared_error: 0.7786 - y2_output_root_mean_squared_error: 1.4840 - val_loss: 3.0508 - val_y1_output_loss: 0.8835 - val_y2_output_loss: 2.1673 - val_y1_output_root_mean_squared_error: 0.9399 - val_y2_output_root_mean_squared_error: 1.4722
# Epoch 106/500
# 62/62 [==============================] - 0s 4ms/step - loss: 3.0116 - y1_output_loss: 0.7870 - y2_output_loss: 2.2245 - y1_output_root_mean_squared_error: 0.8872 - y2_output_root_mean_squared_error: 1.4915 - val_loss: 12.6804 - val_y1_output_loss: 5.0087 - val_y2_output_loss: 7.6717 - val_y1_output_root_mean_squared_error: 2.2380 - val_y2_output_root_mean_squared_error: 2.7698
# Epoch 107/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.5970 - y1_output_loss: 0.6317 - y2_output_loss: 1.9653 - y1_output_root_mean_squared_error: 0.7948 - y2_output_root_mean_squared_error: 1.4019 - val_loss: 2.6618 - val_y1_output_loss: 0.6620 - val_y2_output_loss: 1.9998 - val_y1_output_root_mean_squared_error: 0.8136 - val_y2_output_root_mean_squared_error: 1.4141
# Epoch 108/500
# 62/62 [==============================] - 0s 3ms/step - loss: 1.9357 - y1_output_loss: 0.4470 - y2_output_loss: 1.4886 - y1_output_root_mean_squared_error: 0.6686 - y2_output_root_mean_squared_error: 1.2201 - val_loss: 2.2211 - val_y1_output_loss: 0.5733 - val_y2_output_loss: 1.6478 - val_y1_output_root_mean_squared_error: 0.7572 - val_y2_output_root_mean_squared_error: 1.2837
# Epoch 109/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.0592 - y1_output_loss: 0.4554 - y2_output_loss: 1.6038 - y1_output_root_mean_squared_error: 0.6748 - y2_output_root_mean_squared_error: 1.2664 - val_loss: 2.8511 - val_y1_output_loss: 0.7338 - val_y2_output_loss: 2.1172 - val_y1_output_root_mean_squared_error: 0.8566 - val_y2_output_root_mean_squared_error: 1.4551
# Epoch 110/500
# 62/62 [==============================] - 0s 4ms/step - loss: 1.9540 - y1_output_loss: 0.4445 - y2_output_loss: 1.5095 - y1_output_root_mean_squared_error: 0.6667 - y2_output_root_mean_squared_error: 1.2286 - val_loss: 2.6830 - val_y1_output_loss: 0.4866 - val_y2_output_loss: 2.1964 - val_y1_output_root_mean_squared_error: 0.6976 - val_y2_output_root_mean_squared_error: 1.4820
# Epoch 111/500
# 62/62 [==============================] - 0s 5ms/step - loss: 3.3434 - y1_output_loss: 0.9814 - y2_output_loss: 2.3620 - y1_output_root_mean_squared_error: 0.9907 - y2_output_root_mean_squared_error: 1.5369 - val_loss: 2.7569 - val_y1_output_loss: 0.6710 - val_y2_output_loss: 2.0859 - val_y1_output_root_mean_squared_error: 0.8191 - val_y2_output_root_mean_squared_error: 1.4443
# Epoch 112/500
# 62/62 [==============================] - 0s 5ms/step - loss: 2.1960 - y1_output_loss: 0.4662 - y2_output_loss: 1.7298 - y1_output_root_mean_squared_error: 0.6828 - y2_output_root_mean_squared_error: 1.3152 - val_loss: 11.7575 - val_y1_output_loss: 3.1929 - val_y2_output_loss: 8.5646 - val_y1_output_root_mean_squared_error: 1.7869 - val_y2_output_root_mean_squared_error: 2.9265
# Epoch 113/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.3755 - y1_output_loss: 0.4731 - y2_output_loss: 1.9024 - y1_output_root_mean_squared_error: 0.6878 - y2_output_root_mean_squared_error: 1.3793 - val_loss: 9.4236 - val_y1_output_loss: 3.1358 - val_y2_output_loss: 6.2877 - val_y1_output_root_mean_squared_error: 1.7708 - val_y2_output_root_mean_squared_error: 2.5075
# Epoch 114/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.7306 - y1_output_loss: 0.6105 - y2_output_loss: 2.1201 - y1_output_root_mean_squared_error: 0.7813 - y2_output_root_mean_squared_error: 1.4561 - val_loss: 2.6636 - val_y1_output_loss: 0.4691 - val_y2_output_loss: 2.1946 - val_y1_output_root_mean_squared_error: 0.6849 - val_y2_output_root_mean_squared_error: 1.4814
# Epoch 115/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.1298 - y1_output_loss: 0.5095 - y2_output_loss: 1.6203 - y1_output_root_mean_squared_error: 0.7138 - y2_output_root_mean_squared_error: 1.2729 - val_loss: 2.5988 - val_y1_output_loss: 0.4954 - val_y2_output_loss: 2.1034 - val_y1_output_root_mean_squared_error: 0.7038 - val_y2_output_root_mean_squared_error: 1.4503
# Epoch 116/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.1413 - y1_output_loss: 0.5491 - y2_output_loss: 1.5922 - y1_output_root_mean_squared_error: 0.7410 - y2_output_root_mean_squared_error: 1.2618 - val_loss: 2.0530 - val_y1_output_loss: 0.4919 - val_y2_output_loss: 1.5612 - val_y1_output_root_mean_squared_error: 0.7013 - val_y2_output_root_mean_squared_error: 1.2495
# Epoch 117/500
# 62/62 [==============================] - 0s 5ms/step - loss: 2.6494 - y1_output_loss: 0.7082 - y2_output_loss: 1.9411 - y1_output_root_mean_squared_error: 0.8416 - y2_output_root_mean_squared_error: 1.3932 - val_loss: 5.4543 - val_y1_output_loss: 0.9355 - val_y2_output_loss: 4.5188 - val_y1_output_root_mean_squared_error: 0.9672 - val_y2_output_root_mean_squared_error: 2.1257
# Epoch 118/500
# 62/62 [==============================] - 0s 3ms/step - loss: 2.8869 - y1_output_loss: 0.6942 - y2_output_loss: 2.1927 - y1_output_root_mean_squared_error: 0.8332 - y2_output_root_mean_squared_error: 1.4808 - val_loss: 8.5947 - val_y1_output_loss: 1.5424 - val_y2_output_loss: 7.0523 - val_y1_output_root_mean_squared_error: 1.2419 - val_y2_output_root_mean_squared_error: 2.6556
# Epoch 119/500
# 62/62 [==============================] - 0s 4ms/step - loss: 2.1424 - y1_output_loss: 0.4794 - y2_output_loss: 1.6630 - y1_output_root_mean_squared_error: 0.6924 - y2_output_root_mean_squared_error: 1.2896 - val_loss: 3.2239 - val_y1_output_loss: 0.6425 - val_y2_output_loss: 2.5815 - val_y1_output_root_mean_squared_error: 0.8015 - val_y2_output_root_mean_squared_error: 1.6067
# Epoch 120/500
# ...
# Epoch 461/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3785 - y1_output_loss: 0.1160 - y2_output_loss: 0.2625 - y1_output_root_mean_squared_error: 0.3406 - y2_output_root_mean_squared_error: 0.5123 - val_loss: 0.7690 - val_y1_output_loss: 0.1621 - val_y2_output_loss: 0.6069 - val_y1_output_root_mean_squared_error: 0.4026 - val_y2_output_root_mean_squared_error: 0.7791
# Epoch 462/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4070 - y1_output_loss: 0.1146 - y2_output_loss: 0.2924 - y1_output_root_mean_squared_error: 0.3385 - y2_output_root_mean_squared_error: 0.5408 - val_loss: 1.1569 - val_y1_output_loss: 0.1564 - val_y2_output_loss: 1.0005 - val_y1_output_root_mean_squared_error: 0.3955 - val_y2_output_root_mean_squared_error: 1.0003
# Epoch 463/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.5935 - y1_output_loss: 0.1790 - y2_output_loss: 0.4144 - y1_output_root_mean_squared_error: 0.4231 - y2_output_root_mean_squared_error: 0.6438 - val_loss: 0.8313 - val_y1_output_loss: 0.2065 - val_y2_output_loss: 0.6248 - val_y1_output_root_mean_squared_error: 0.4545 - val_y2_output_root_mean_squared_error: 0.7904
# Epoch 464/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5845 - y1_output_loss: 0.1640 - y2_output_loss: 0.4205 - y1_output_root_mean_squared_error: 0.4049 - y2_output_root_mean_squared_error: 0.6484 - val_loss: 1.0235 - val_y1_output_loss: 0.1510 - val_y2_output_loss: 0.8724 - val_y1_output_root_mean_squared_error: 0.3886 - val_y2_output_root_mean_squared_error: 0.9340
# Epoch 465/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3678 - y1_output_loss: 0.1181 - y2_output_loss: 0.2497 - y1_output_root_mean_squared_error: 0.3436 - y2_output_root_mean_squared_error: 0.4997 - val_loss: 0.7651 - val_y1_output_loss: 0.1866 - val_y2_output_loss: 0.5785 - val_y1_output_root_mean_squared_error: 0.4320 - val_y2_output_root_mean_squared_error: 0.7606
# Epoch 466/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4686 - y1_output_loss: 0.1231 - y2_output_loss: 0.3455 - y1_output_root_mean_squared_error: 0.3509 - y2_output_root_mean_squared_error: 0.5878 - val_loss: 0.8741 - val_y1_output_loss: 0.1968 - val_y2_output_loss: 0.6773 - val_y1_output_root_mean_squared_error: 0.4436 - val_y2_output_root_mean_squared_error: 0.8230
# Epoch 467/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4148 - y1_output_loss: 0.1174 - y2_output_loss: 0.2974 - y1_output_root_mean_squared_error: 0.3426 - y2_output_root_mean_squared_error: 0.5454 - val_loss: 1.4869 - val_y1_output_loss: 0.1892 - val_y2_output_loss: 1.2977 - val_y1_output_root_mean_squared_error: 0.4350 - val_y2_output_root_mean_squared_error: 1.1392
# Epoch 468/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4420 - y1_output_loss: 0.1227 - y2_output_loss: 0.3193 - y1_output_root_mean_squared_error: 0.3503 - y2_output_root_mean_squared_error: 0.5651 - val_loss: 0.8299 - val_y1_output_loss: 0.1848 - val_y2_output_loss: 0.6450 - val_y1_output_root_mean_squared_error: 0.4299 - val_y2_output_root_mean_squared_error: 0.8031
# Epoch 469/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4090 - y1_output_loss: 0.1270 - y2_output_loss: 0.2821 - y1_output_root_mean_squared_error: 0.3563 - y2_output_root_mean_squared_error: 0.5311 - val_loss: 1.2230 - val_y1_output_loss: 0.2972 - val_y2_output_loss: 0.9258 - val_y1_output_root_mean_squared_error: 0.5452 - val_y2_output_root_mean_squared_error: 0.9622
# Epoch 470/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4149 - y1_output_loss: 0.1146 - y2_output_loss: 0.3003 - y1_output_root_mean_squared_error: 0.3385 - y2_output_root_mean_squared_error: 0.5480 - val_loss: 0.7908 - val_y1_output_loss: 0.1787 - val_y2_output_loss: 0.6121 - val_y1_output_root_mean_squared_error: 0.4227 - val_y2_output_root_mean_squared_error: 0.7824
# Epoch 471/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3956 - y1_output_loss: 0.1207 - y2_output_loss: 0.2749 - y1_output_root_mean_squared_error: 0.3474 - y2_output_root_mean_squared_error: 0.5243 - val_loss: 0.7757 - val_y1_output_loss: 0.1850 - val_y2_output_loss: 0.5907 - val_y1_output_root_mean_squared_error: 0.4301 - val_y2_output_root_mean_squared_error: 0.7686
# Epoch 472/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5620 - y1_output_loss: 0.1459 - y2_output_loss: 0.4161 - y1_output_root_mean_squared_error: 0.3820 - y2_output_root_mean_squared_error: 0.6451 - val_loss: 0.8923 - val_y1_output_loss: 0.2421 - val_y2_output_loss: 0.6502 - val_y1_output_root_mean_squared_error: 0.4920 - val_y2_output_root_mean_squared_error: 0.8064
# Epoch 473/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4777 - y1_output_loss: 0.1499 - y2_output_loss: 0.3278 - y1_output_root_mean_squared_error: 0.3871 - y2_output_root_mean_squared_error: 0.5726 - val_loss: 1.6134 - val_y1_output_loss: 0.3668 - val_y2_output_loss: 1.2466 - val_y1_output_root_mean_squared_error: 0.6056 - val_y2_output_root_mean_squared_error: 1.1165
# Epoch 474/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4763 - y1_output_loss: 0.1270 - y2_output_loss: 0.3493 - y1_output_root_mean_squared_error: 0.3564 - y2_output_root_mean_squared_error: 0.5910 - val_loss: 0.7872 - val_y1_output_loss: 0.1583 - val_y2_output_loss: 0.6289 - val_y1_output_root_mean_squared_error: 0.3979 - val_y2_output_root_mean_squared_error: 0.7930
# Epoch 475/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3493 - y1_output_loss: 0.1089 - y2_output_loss: 0.2405 - y1_output_root_mean_squared_error: 0.3300 - y2_output_root_mean_squared_error: 0.4904 - val_loss: 1.4052 - val_y1_output_loss: 0.2803 - val_y2_output_loss: 1.1249 - val_y1_output_root_mean_squared_error: 0.5294 - val_y2_output_root_mean_squared_error: 1.0606
# Epoch 476/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4291 - y1_output_loss: 0.1178 - y2_output_loss: 0.3112 - y1_output_root_mean_squared_error: 0.3433 - y2_output_root_mean_squared_error: 0.5579 - val_loss: 0.7837 - val_y1_output_loss: 0.1695 - val_y2_output_loss: 0.6141 - val_y1_output_root_mean_squared_error: 0.4118 - val_y2_output_root_mean_squared_error: 0.7837
# Epoch 477/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4007 - y1_output_loss: 0.1241 - y2_output_loss: 0.2766 - y1_output_root_mean_squared_error: 0.3523 - y2_output_root_mean_squared_error: 0.5259 - val_loss: 1.1022 - val_y1_output_loss: 0.2617 - val_y2_output_loss: 0.8405 - val_y1_output_root_mean_squared_error: 0.5115 - val_y2_output_root_mean_squared_error: 0.9168
# Epoch 478/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4216 - y1_output_loss: 0.1344 - y2_output_loss: 0.2872 - y1_output_root_mean_squared_error: 0.3666 - y2_output_root_mean_squared_error: 0.5359 - val_loss: 1.2949 - val_y1_output_loss: 0.4198 - val_y2_output_loss: 0.8752 - val_y1_output_root_mean_squared_error: 0.6479 - val_y2_output_root_mean_squared_error: 0.9355
# Epoch 479/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4336 - y1_output_loss: 0.1443 - y2_output_loss: 0.2893 - y1_output_root_mean_squared_error: 0.3799 - y2_output_root_mean_squared_error: 0.5379 - val_loss: 0.8760 - val_y1_output_loss: 0.2004 - val_y2_output_loss: 0.6756 - val_y1_output_root_mean_squared_error: 0.4477 - val_y2_output_root_mean_squared_error: 0.8220
# Epoch 480/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3863 - y1_output_loss: 0.1161 - y2_output_loss: 0.2702 - y1_output_root_mean_squared_error: 0.3408 - y2_output_root_mean_squared_error: 0.5198 - val_loss: 0.7957 - val_y1_output_loss: 0.1658 - val_y2_output_loss: 0.6299 - val_y1_output_root_mean_squared_error: 0.4072 - val_y2_output_root_mean_squared_error: 0.7937
# Epoch 481/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3408 - y1_output_loss: 0.1160 - y2_output_loss: 0.2248 - y1_output_root_mean_squared_error: 0.3406 - y2_output_root_mean_squared_error: 0.4741 - val_loss: 1.2260 - val_y1_output_loss: 0.2410 - val_y2_output_loss: 0.9850 - val_y1_output_root_mean_squared_error: 0.4909 - val_y2_output_root_mean_squared_error: 0.9925
# Epoch 482/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3552 - y1_output_loss: 0.1167 - y2_output_loss: 0.2384 - y1_output_root_mean_squared_error: 0.3416 - y2_output_root_mean_squared_error: 0.4883 - val_loss: 0.8041 - val_y1_output_loss: 0.1553 - val_y2_output_loss: 0.6488 - val_y1_output_root_mean_squared_error: 0.3941 - val_y2_output_root_mean_squared_error: 0.8055
# Epoch 483/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4220 - y1_output_loss: 0.1170 - y2_output_loss: 0.3051 - y1_output_root_mean_squared_error: 0.3420 - y2_output_root_mean_squared_error: 0.5523 - val_loss: 0.7600 - val_y1_output_loss: 0.1477 - val_y2_output_loss: 0.6123 - val_y1_output_root_mean_squared_error: 0.3843 - val_y2_output_root_mean_squared_error: 0.7825
# Epoch 484/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3632 - y1_output_loss: 0.1062 - y2_output_loss: 0.2570 - y1_output_root_mean_squared_error: 0.3259 - y2_output_root_mean_squared_error: 0.5070 - val_loss: 0.7555 - val_y1_output_loss: 0.1602 - val_y2_output_loss: 0.5953 - val_y1_output_root_mean_squared_error: 0.4002 - val_y2_output_root_mean_squared_error: 0.7715
# Epoch 485/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4631 - y1_output_loss: 0.1407 - y2_output_loss: 0.3224 - y1_output_root_mean_squared_error: 0.3750 - y2_output_root_mean_squared_error: 0.5678 - val_loss: 0.9611 - val_y1_output_loss: 0.2033 - val_y2_output_loss: 0.7578 - val_y1_output_root_mean_squared_error: 0.4509 - val_y2_output_root_mean_squared_error: 0.8705
# Epoch 486/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4039 - y1_output_loss: 0.1344 - y2_output_loss: 0.2695 - y1_output_root_mean_squared_error: 0.3665 - y2_output_root_mean_squared_error: 0.5192 - val_loss: 0.8195 - val_y1_output_loss: 0.1787 - val_y2_output_loss: 0.6408 - val_y1_output_root_mean_squared_error: 0.4227 - val_y2_output_root_mean_squared_error: 0.8005
# Epoch 487/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3437 - y1_output_loss: 0.1062 - y2_output_loss: 0.2375 - y1_output_root_mean_squared_error: 0.3258 - y2_output_root_mean_squared_error: 0.4874 - val_loss: 0.7579 - val_y1_output_loss: 0.1920 - val_y2_output_loss: 0.5659 - val_y1_output_root_mean_squared_error: 0.4381 - val_y2_output_root_mean_squared_error: 0.7523
# Epoch 488/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4686 - y1_output_loss: 0.1313 - y2_output_loss: 0.3373 - y1_output_root_mean_squared_error: 0.3624 - y2_output_root_mean_squared_error: 0.5808 - val_loss: 1.4541 - val_y1_output_loss: 0.2183 - val_y2_output_loss: 1.2357 - val_y1_output_root_mean_squared_error: 0.4673 - val_y2_output_root_mean_squared_error: 1.1116
# Epoch 489/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4034 - y1_output_loss: 0.1147 - y2_output_loss: 0.2888 - y1_output_root_mean_squared_error: 0.3386 - y2_output_root_mean_squared_error: 0.5374 - val_loss: 0.7491 - val_y1_output_loss: 0.1634 - val_y2_output_loss: 0.5857 - val_y1_output_root_mean_squared_error: 0.4043 - val_y2_output_root_mean_squared_error: 0.7653
# Epoch 490/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3450 - y1_output_loss: 0.1112 - y2_output_loss: 0.2338 - y1_output_root_mean_squared_error: 0.3335 - y2_output_root_mean_squared_error: 0.4835 - val_loss: 0.7987 - val_y1_output_loss: 0.1686 - val_y2_output_loss: 0.6301 - val_y1_output_root_mean_squared_error: 0.4107 - val_y2_output_root_mean_squared_error: 0.7938
# Epoch 491/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4058 - y1_output_loss: 0.1140 - y2_output_loss: 0.2918 - y1_output_root_mean_squared_error: 0.3376 - y2_output_root_mean_squared_error: 0.5402 - val_loss: 0.7567 - val_y1_output_loss: 0.1747 - val_y2_output_loss: 0.5820 - val_y1_output_root_mean_squared_error: 0.4180 - val_y2_output_root_mean_squared_error: 0.7629
# Epoch 492/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4136 - y1_output_loss: 0.1327 - y2_output_loss: 0.2809 - y1_output_root_mean_squared_error: 0.3643 - y2_output_root_mean_squared_error: 0.5300 - val_loss: 0.7661 - val_y1_output_loss: 0.1603 - val_y2_output_loss: 0.6058 - val_y1_output_root_mean_squared_error: 0.4004 - val_y2_output_root_mean_squared_error: 0.7784
# Epoch 493/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3863 - y1_output_loss: 0.1283 - y2_output_loss: 0.2580 - y1_output_root_mean_squared_error: 0.3582 - y2_output_root_mean_squared_error: 0.5080 - val_loss: 0.7997 - val_y1_output_loss: 0.1656 - val_y2_output_loss: 0.6341 - val_y1_output_root_mean_squared_error: 0.4070 - val_y2_output_root_mean_squared_error: 0.7963
# Epoch 494/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4086 - y1_output_loss: 0.1176 - y2_output_loss: 0.2910 - y1_output_root_mean_squared_error: 0.3430 - y2_output_root_mean_squared_error: 0.5394 - val_loss: 0.7459 - val_y1_output_loss: 0.1724 - val_y2_output_loss: 0.5735 - val_y1_output_root_mean_squared_error: 0.4152 - val_y2_output_root_mean_squared_error: 0.7573
# Epoch 495/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3191 - y1_output_loss: 0.1071 - y2_output_loss: 0.2120 - y1_output_root_mean_squared_error: 0.3273 - y2_output_root_mean_squared_error: 0.4604 - val_loss: 0.9188 - val_y1_output_loss: 0.2905 - val_y2_output_loss: 0.6283 - val_y1_output_root_mean_squared_error: 0.5390 - val_y2_output_root_mean_squared_error: 0.7926
# Epoch 496/500
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3317 - y1_output_loss: 0.1099 - y2_output_loss: 0.2218 - y1_output_root_mean_squared_error: 0.3316 - y2_output_root_mean_squared_error: 0.4709 - val_loss: 0.7650 - val_y1_output_loss: 0.1774 - val_y2_output_loss: 0.5876 - val_y1_output_root_mean_squared_error: 0.4212 - val_y2_output_root_mean_squared_error: 0.7665
# Epoch 497/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3885 - y1_output_loss: 0.1234 - y2_output_loss: 0.2651 - y1_output_root_mean_squared_error: 0.3513 - y2_output_root_mean_squared_error: 0.5149 - val_loss: 1.0415 - val_y1_output_loss: 0.2667 - val_y2_output_loss: 0.7748 - val_y1_output_root_mean_squared_error: 0.5164 - val_y2_output_root_mean_squared_error: 0.8802
# Epoch 498/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3984 - y1_output_loss: 0.1217 - y2_output_loss: 0.2767 - y1_output_root_mean_squared_error: 0.3489 - y2_output_root_mean_squared_error: 0.5260 - val_loss: 0.9379 - val_y1_output_loss: 0.2051 - val_y2_output_loss: 0.7328 - val_y1_output_root_mean_squared_error: 0.4529 - val_y2_output_root_mean_squared_error: 0.8560
# Epoch 499/500
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3849 - y1_output_loss: 0.1265 - y2_output_loss: 0.2584 - y1_output_root_mean_squared_error: 0.3556 - y2_output_root_mean_squared_error: 0.5083 - val_loss: 1.2188 - val_y1_output_loss: 0.3105 - val_y2_output_loss: 0.9083 - val_y1_output_root_mean_squared_error: 0.5573 - val_y2_output_root_mean_squared_error: 0.9530
# Epoch 500/500
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4142 - y1_output_loss: 0.1248 - y2_output_loss: 0.2894 - y1_output_root_mean_squared_error: 0.3533 - y2_output_root_mean_squared_error: 0.5380 - val_loss: 1.4376 - val_y1_output_loss: 0.2223 - val_y2_output_loss: 1.2153 - val_y1_output_root_mean_squared_error: 0.4715 - val_y2_output_root_mean_squared_error: 1.1024

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {:.4f}, Y1_loss = {:.4f}, Y1_mse = {:.4f}, Y2_loss = {:.4f}, Y2_mse = {:.4f}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 5/5 [==============================] - 0s 4ms/step - loss: 1.4376 - y1_output_loss: 0.2223 - y2_output_loss: 1.2153 - y1_output_root_mean_squared_error: 0.4715 - y2_output_root_mean_squared_error: 1.1024
# Loss = 1.4376, Y1_loss = 0.2223, Y1_mse = 0.4715, Y2_loss = 1.2153, Y2_mse = 1.1024

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
# Out:
# 5/5 [==============================] - 0s 3ms/step
